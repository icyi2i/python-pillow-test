# %%
from PIL import Image, ImageOps,

# %%
img = Image.open("./test.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=622x417 at 0x197948FB100>

# %%
x = img.resize((8,8), Image.FIXED).resize((440,440), Image.NEAREST)
x
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x197971855B0>

# %%
x = ImageOps.grayscale(x)
x
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x19796B78CD0>

# %%
x.save("test-grey-pix.png")

# %%
x = x.convert('P', palette=Image.ADAPTIVE, colors=8)
x
# Out:
# <PIL.Image.Image image mode=P size=400x400 at 0x19796A275E0>

# %%
import numpy as np

# %%
xarr = np.array(x.resize((8,8), Image.FIXED))
xarr
# Out:
# array([[6, 6, 6, 5, 1, 1, 4, 6],
#        [5, 5, 5, 0, 1, 7, 3, 6],
#        [4, 4, 2, 1, 1, 2, 3, 6],
#        [6, 7, 7, 4, 1, 1, 3, 7],
#        [6, 5, 4, 5, 2, 1, 2, 7],
#        [4, 4, 4, 4, 1, 0, 1, 5],
#        [3, 3, 3, 3, 0, 0, 0, 6],
#        [3, 3, 3, 1, 0, 0, 1, 6]], dtype=uint8)

# %%
xarr.shape = (1,64)
xarr
# Out:
# array([[6, 6, 6, 5, 1, 1, 4, 6, 5, 5, 5, 0, 1, 7, 3, 6, 4, 4, 2, 1, 1, 2,
#         3, 6, 6, 7, 7, 4, 1, 1, 3, 7, 6, 5, 4, 5, 2, 1, 2, 7, 4, 4, 4, 4,
#         1, 0, 1, 5, 3, 3, 3, 3, 0, 0, 0, 6, 3, 3, 3, 1, 0, 0, 1, 6]],
#       dtype=uint8)

# %%
set(xarr[0])
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
FE
- uploads a picture
- save in BE
BE
- create pix image
- send back to FE
FE
- draw
